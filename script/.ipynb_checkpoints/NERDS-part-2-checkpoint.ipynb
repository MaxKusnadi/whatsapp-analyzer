# %% [markdown]
# Part 1 can be found [here](https://maxkusnadi.github.io/whatsapp-analyzer/NERDS.html)

# %% [markdown]
# # Preprocessing

# %%
# Importing pandas and ggplot
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np

sns.set_style("whitegrid")
sns.set(font_scale=1.5)

# Open the csv file
data = pd.read_csv("../data/NERDS.csv")

# Convert Date string to datetime format
data['Date'] = pd.to_datetime(data['Date'], format="%d/%m/%Y %H:%M")

# %% [markdown]
# # Most Fav Words

# %% [markdown]
# ### Referring to this picture ![lol](http://i.imgur.com/mlPZgna.png)  Fav word 1.0
# ### It is really not meaningful as it contains stopwords. So we need to remove stopwords e.g. "gua", "gw" etc and try to impose minimum number of words

# %%
# WA does not capture media (video etc) in its text file. 
# Instead, all the media shared is replaced by <Media ommited>
# We have to clean it for fairness sake

# data_words = data[data['Text'] != '<Media omitted>']

# data_words['Text'].apply(str)

# %%
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["gua", "gw"], ngram_range=(1,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Lol? Most of the words are just names. Let's try to increase the minimum number of words included to 2

# %%
vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["gua", "gw"], ngram_range=(2,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Interesting... Most of these phrases are questions and invitations. Let's increase the minimum no of words to 3

# %%
vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["gua", "gw"], ngram_range=(3,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Hmmm... LOL. Okay let's include all these words to the stop words list

# %%
vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"], ngram_range=(1,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Seems like a person whose name includes "to" is very popular. Let's see what they have if minimum words are 2

# %%
vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Wot.. Mostly asking time and happy birthday. Seems like pc com is the most favourite place too. 'Open jio' and 'yuk ben' may have something interesting. Let's explore more

# %%
vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(3,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Hmm oh well.. Let's exclude all the 'asking time' questions

# %%
vect = CountVectorizer(min_df=15, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))


vect.fit(data_words['Text'])

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### If one were to generate sentences from this, it would be **'hi guys, happy birthday. open jio hari ini (di) pc com.**

# %% [markdown]
# ## Conclusion
#
# ### - This group chat is mainly to ask questions and invite people
# ### - "to" is the most called name
# ### - PC com is mentioned the most

# %% [markdown]
# # What are those peaks?

# %% [markdown]
# ### Referring to ![LOL](http://i.imgur.com/eMWIrrc.png) Number of chats over time (month-year)

# %% [markdown]
# ### We can see see that there are peaks around Apr-May 15 (1), Aug-Oct 15(2), Jan-Feb 16 (3) and Jul-Sep 16 (4). What were we talking then?

# %% [markdown]
# ## Peak 1 Apr-May 2015

# %%
data_words['Month_Year'] = data['Date'].apply(lambda x:x.date().strftime('%m/%Y'))
# Out:
# /home/max/project/whatsapp-analyzer/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
vect = CountVectorizer(min_df=15, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(1,3))

vect.fit(data_words['Text'][(data_words['Month_Year'] == "04/2015") | (data_words['Month_Year'] == "05/2015")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Pretty similar. Let's increase minimum number of words to 2

# %%
vect = CountVectorizer(min_df=10, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Month_Year'] == "04/2015") | (data_words['Month_Year'] == "05/2015")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Open jio pc com? Hmm... Exam period maybe. Notable findings : apa sih mot

# %% [markdown]
# ## Peak 2 Aug-Oct 2015

# %%
vect = CountVectorizer(min_df=10, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Month_Year'] == "08/2015") | (data_words['Month_Year'] == "09/2015") | (data_words['Month_Year'] == "10/2015")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Peak period for open jio, makan mana, ameen order and bing bing. Thought provoking. But still pc com

# %% [markdown]
# ## Peak 3 Jan-Feb 2016

# %%
vect = CountVectorizer(min_df=8, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Month_Year'] == "01/2016") | (data_words['Month_Year'] == "02/2016")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### CNY and new year. open jio is still there. Unsuprisingly, pc com too

# %% [markdown]
# # Peak 4 July-Sept 16

# %%
vect = CountVectorizer(min_df=10, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Month_Year'] == "07/2016") | (data_words['Month_Year'] == "08/2016") | (data_words['Month_Year'] == "09/2016")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Hmm open jio mookata sabtu sore seemed to be the trending topic back then. Seems we had a surge in birthday celebration as well

# %% [markdown]
# # It's High Noon...

# %% [markdown]
# ### Referring to ![LOL](http://i.imgur.com/Cjds7Em.png) Number of chats over time (hour)

# %% [markdown]
# ### We can see 3 peaks again, 12pm (1), 5-6pm (2), 10-11pm (3). What happen during **high noon**?

# %% [markdown]
# # Peak 1 (12 pm)

# %%
data_words['Hour'] = data_words['Date'].apply(lambda x:x.time().strftime('%H'))
# Out:
# /home/max/project/whatsapp-analyzer/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
vect = CountVectorizer(min_df=10, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Hour'] == "12")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Possible convo:
#
# ### Bena: "lunch anyone?"
#
# ### Topaz: "yuk ben. lunch utown?"
#
# ### Bena: "yuk paz"

# %% [markdown]
# # Peak 2 (5-6 pm)

# %%
vect = CountVectorizer(min_df=8, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Hour'] == "17") | (data_words['Hour'] == "18")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Open jio extra credit makan utown

# %% [markdown]
# # Peak 3 (10-11pm)

# %%
vect = CountVectorizer(min_df=8, max_df=0.8, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Hour'] == "22") | (data_words['Hour'] == "23")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Fav order from ameen: **teh cino**

# %% [markdown]
# # Who says what?

# %% [markdown]
# ### Referring to ![LOL](http://i.imgur.com/Vn6ngPs.png) 10 Most active members

# %% [markdown]
# ### What were those people saying? Let's explore

# %% [markdown]
# # Karin

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(1,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Karin")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### to? Let's increase the minimum number of words

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Karin")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### ok mot

# %% [markdown]
# # Benaya

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(1,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Benaya")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### to again????

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Benaya")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### yuk ben

# %% [markdown]
# # Toto

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(1,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Toto")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Even toto calling to the most. Prolly it's the english word 'to'. Nobody knows

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Toto")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### pc com... hmm now we know where all the 'pc com' comes from

# %% [markdown]
# # Ida

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(1,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Ida")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Ok enough of 'to'. Let's just focus on 2 words or more

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Ida")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Open jio hr ni. Hmm ok

# %% [markdown]
# # Jason

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Jason")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Wooooooot. Lunch at the deck?

# %% [markdown]
# # Topaz (last)

# %%
vect = CountVectorizer(min_df=10, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Topaz")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Lunch with Bena. Proving earlier convo

# %% [markdown]
# ## How bout me?

# %%
vect = CountVectorizer(min_df=5, max_df=1.0, stop_words=["jam", "jm","di", "lu", "ga", "gua", "gw", "lol", "ada", "ad", "yang", "yg", "mau", "mw", "mw"],
                       ngram_range=(2,3))

vect.fit(data_words['Text'][(data_words['Name'] == "Max K")]) 

text_dtm = vect.transform(data_words['Text'])
text_dtm

word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# ### Oh well...
