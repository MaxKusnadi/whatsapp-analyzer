# %% [markdown]
# ### Foreword
#
# Hi guys, this is a visualisation of a Whatsapp chat. I used one of my WA groups as the dataset. For those who are interested in doing similar thing, you can look through this piece and feel free to ask questions. For the less geeky one, just skip the codes

# %% [markdown]
# ### Getting the dataset
# How to get WA chat data:
# - Open WA app on your mobile phone
# - Click setting and choose *Email chat*
# - Email it to yourself
#
# How to convert WA chat file (.txt) to csv:
# - Go to [link](https://github.com/MaxKusnadi/whatsapp-analyzer) and download *text_to_csv.py*
# - Change the variable *TEXT_LOCATION* to your txt location and *CSV_LOCATION* to your csv location.
# - Run the program. I use Python 3.5

# %% [markdown]
# ## Preprocessing

# %%
# Importing pandas and ggplot
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np

# %%
sns.set_style("whitegrid")
sns.set(font_scale=1.5)

# %%
# Open the csv file
data = pd.read_csv("../data/NERDS.csv")

# %%
data.head()
# Out:
#                Date             Name                  Text
# 0  11/04/2015 23:22            Grace                 dayum
# 1  11/04/2015 23:53  ‪+65 8555 0251‬          Free d mana!
# 2  11/04/2015 23:53  ‪+65 8555 0251‬                     ?
# 3  11/04/2015 23:59            Grace   di ben and jerry's!
# 4  12/04/2015 00:10  ‪+65 8555 0251‬       <Media omitted>

# %%
# Convert Date string to datetime format
data['Date'] = pd.to_datetime(data['Date'], format="%d/%m/%Y %H:%M")

# %%
data.head()
# Out:
#                  Date             Name                  Text
# 0 2015-04-11 23:22:00            Grace                 dayum
# 1 2015-04-11 23:53:00  ‪+65 8555 0251‬          Free d mana!
# 2 2015-04-11 23:53:00  ‪+65 8555 0251‬                     ?
# 3 2015-04-11 23:59:00            Grace   di ben and jerry's!
# 4 2015-04-12 00:10:00  ‪+65 8555 0251‬       <Media omitted>

# %% [markdown]
# ## Total Chats

# %%
data.shape
# Out:
# (39871, 3)

# %% [markdown]
# **39,871** since 11/4/2015

# %% [markdown]
# ## Total Media Shared (Videos, Pictures, etc)

# %%
data['Text'][data['Text'] == ' <Media omitted>'].shape
# Out:
# (1154,)

# %% [markdown]
# **1154** media shared

# %% [markdown]
# # 10 Most Active Members
# Calculated based on how many times a person speaks

# %%
active_members = data['Name'].value_counts()

df = pd.DataFrame({'name': active_members.index[0:10], 'count': active_members.values[0:10]})

plot = sns.barplot(x="name", y="count", data=df)
plot.figure.set_size_inches(20,10)

# %% [markdown]
# # 10 Most Inactive Members
# Idem

# %%
inactive_members = data['Name'].value_counts(ascending=True)

df = pd.DataFrame({'name': inactive_members.index[0:10], 'count': inactive_members.values[0:10]})

plot = sns.barplot(x="name", y="count", data=df)
plot.figure.set_size_inches(20,10)

# %% [markdown]
# # 10 Members with the Highest Number of Words Written
# Calculated based the number of words written by a person

# %%
# -1 because of some whitespace problems
def count_words(text):
    words = text.split(" ")
    return len(words) - 1

# %%
# WA does not capture media (video etc) in its text file. 
# Instead, all the media shared is replaced by <Media ommited>
# We have to clean it for fairness sake

data_words = data[data['Text'] != ' <Media omitted>']

# %%
data_words['No_of_words'] = data_words['Text'].apply(count_words)
# Out:
# /home/max/project/whatsapp-analyzer/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_words.head()
# Out:
#                  Date             Name                                   Text  \
# 0 2015-04-11 23:22:00            Grace                                  dayum
# 1 2015-04-11 23:53:00  ‪+65 8555 0251‬                           Free d mana!
# 2 2015-04-11 23:53:00  ‪+65 8555 0251‬                                      ?
# 3 2015-04-11 23:59:00            Grace                    di ben and jerry's!
# 5 2015-04-12 00:10:00  ‪+65 8555 0251‬   Yg ambil maths ma cs jawabannya apa?
#
#    No_of_words
# 0            1
# 1            3
# 2            1
# 3            4
# 5            7

# %%
df = pd.DataFrame()
df['Name'] = data_words['Name'].unique()

# %%
def sum_words(name):
    count = data_words['No_of_words'][data_words['Name'] == name].sum()
    return count

# %%
df['Total words'] = df['Name'].apply(sum_words)

# %%
df = df.sort_values('Total words', ascending=False)

# %%
plot = sns.barplot(x="Name", y="Total words", data=df[0:10])
plot.figure.set_size_inches(20,10)

# %% [markdown]
# # 10 Members with the Highest Words per Chats

# %%
active_members = data['Name'].value_counts()
def count_average(name):
    words = df['Total words'][df['Name'] == name].sum()
    total = active_members[name]
    return words/total

# %%
df['Average'] = df['Name'].apply(count_average)
df = df.sort_values('Average', ascending=False)
plot = sns.barplot(x="Name", y="Average", data=df[0:10])
plot.figure.set_size_inches(20,10)

# %% [markdown]
# # Favourite Word (No Threshold)

# %%
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(min_df=15, max_df=1.0)

# %%
vect.fit(data_words['Text'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=15,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
text_dtm = vect.transform(data_words['Text'])
text_dtm
# Out:
# <38717x1185 sparse matrix of type '<class 'numpy.int64'>'
# 	with 102108 stored elements in Compressed Sparse Row format>

# %%
word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

# %%
word_freq_df.sort_values('occurrences', ascending=False)
# Out:
#       occurrences       term
# 420          4291         gw
# 646          1716        lol
# 282          1686         di
# 376          1392         ga
# 22           1374        ada
# 655          1353         lu
# 699          1317        mau
# 1170         1303         yg
# 1072         1291         to
# 1158         1099         ya
# 424          1057       haha
# 123           967        ben
# 418           916       guys
# 415           855        gua
# 1179          853        yuk
# 426           761     hahaha
# 21            711         ad
# 1048          683        the
# 674           663      makan
# 254           656         da
# 535           628       kalo
# 555           618         ke
# 34            618        aja
# 511           589         je
# 494           588        itu
# 397           539         gk
# 505           529        jam
# 633           486         lg
# 960           481        sih
# 1162          481       yang
# ...           ...        ...
# 144            15    bingung
# 149            15      bknny
# 1109           15     urgent
# 153            15       blkg
# 136            15   biasanya
# 575            15       kind
# 116            15       been
# 114            15      bebeb
# 614            15     lantai
# 1085           15      trump
# 989            15       spam
# 324            15     during
# 108            15     bawain
# 294            15       dket
# 502            15    jadinya
# 1128           15      wants
# 184            15  bumblebee
# 903            15      reply
# 188            15      butuh
# 401            15      gonna
# 1134           15    website
# 809            15      nyari
# 641            15        lix
# 531            15      kalah
# 820            15       oke2
# 201            15       card
# 292            15     disitu
# 1104           15      ultah
# 211            15     charge
# 1101           15       ujan
#
# [1185 rows x 2 columns]

# %%
wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# # **NOT MEANINGFUL**

# %% [markdown]
# # Favourite Word 2.0 (Max Threshold = 1000)

# %%
vect = CountVectorizer(min_df=15, max_df=1000)
text_dtm = vect.fit_transform(data_words['Text'])
word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# # Favourite Word 3.0 (Max Threshold=100)

# %%
vect = CountVectorizer(min_df=15, max_df=100)
text_dtm = vect.fit_transform(data_words['Text'])
word_freq_df = pd.DataFrame({'term': vect.get_feature_names(), 'occurrences':np.asarray(text_dtm.sum(axis=0)).ravel().tolist()})

wc = WordCloud(width=1920, height=1080, scale=1,
               min_font_size=18, margin=20, 
               random_state=27,
               background_color='#111')
wc.generate_from_frequencies(zip(word_freq_df['term'], word_freq_df['occurrences']))
sns.plt.figure( figsize=(16,8) )
sns.plt.axis("off")
sns.plt.imshow(wc)

# %% [markdown]
# # Number of Chats over Time

# %%
data['Short Date'] = data['Date'].apply(lambda x:x.date().strftime('%m/%Y'))
data['Short Date'] = pd.to_datetime(data['Short Date'], format="%m/%Y")
data
# Out:
#                      Date              Name  \
# 0     2015-04-11 23:22:00             Grace
# 1     2015-04-11 23:53:00   ‪+65 8555 0251‬
# 2     2015-04-11 23:53:00   ‪+65 8555 0251‬
# 3     2015-04-11 23:59:00             Grace
# 4     2015-04-12 00:10:00   ‪+65 8555 0251‬
# 5     2015-04-12 00:10:00   ‪+65 8555 0251‬
# 6     2015-04-12 00:21:00   ‪+65 9148 9532‬
# 7     2015-04-12 00:21:00   ‪+65 8555 0251‬
# 8     2015-04-12 00:21:00   ‪+65 9148 9532‬
# 9     2015-04-12 00:22:00   ‪+65 8555 0251‬
# 10    2015-04-12 00:24:00             Max K
# 11    2015-04-12 00:25:00   ‪+65 8555 0251‬
# 12    2015-04-12 00:26:00   ‪+65 9148 9532‬
# 13    2015-04-12 00:26:00   ‪+65 9148 9532‬
# 14    2015-04-12 00:26:00   ‪+65 8555 0251‬
# 15    2015-04-12 00:26:00             Karin
# 16    2015-04-12 00:27:00   ‪+65 9148 9532‬
# 17    2015-04-12 00:27:00   ‪+65 9148 9532‬
# 18    2015-04-12 00:32:00   ‪+65 9220 4047‬
# 19    2015-04-12 00:32:00   ‪+65 9220 4047‬
# 20    2015-04-12 00:33:00   ‪+65 9220 4047‬
# 21    2015-04-12 00:33:00   ‪+65 9220 4047‬
# 22    2015-04-12 00:35:00   ‪+65 8555 0251‬
# 23    2015-04-12 09:29:00             Topaz
# 24    2015-04-12 09:30:00   ‪+65 9220 4047‬
# 25    2015-04-12 09:32:00               Dea
# 26    2015-04-12 09:32:00               Dea
# 27    2015-04-12 09:33:00   ‪+65 9220 4047‬
# 28    2015-04-12 09:34:00             Topaz
# 29    2015-04-12 09:34:00             Topaz
# ...                   ...               ...
# 39841 2017-02-13 13:00:00             Tasya
# 39842 2017-02-13 13:02:00              Toto
# 39843 2017-02-13 15:26:00      Cindy Amelia
# 39844 2017-02-13 15:28:00  Renaldo Hermawan
# 39845 2017-02-13 15:28:00  Renaldo Hermawan
# 39846 2017-02-13 15:29:00      Cindy Amelia
# 39847 2017-02-13 15:43:00            Evelyn
# 39848 2017-02-13 15:46:00             Marco
# 39849 2017-02-13 15:46:00            Benaya
# 39850 2017-02-13 15:46:00      Cindy Amelia
# 39851 2017-02-13 15:46:00      Cindy Amelia
# 39852 2017-02-13 15:46:00             Marco
# 39853 2017-02-13 15:46:00            Benaya
# 39854 2017-02-13 15:47:00            Benaya
# 39855 2017-02-13 16:07:00             Karin
# 39856 2017-02-13 16:08:00             Karin
# 39857 2017-02-13 16:36:00      Cindy Amelia
# 39858 2017-02-13 16:36:00      Cindy Amelia
# 39859 2017-02-13 16:36:00      Cindy Amelia
# 39860 2017-02-13 16:36:00            Evelyn
# 39861 2017-02-13 16:37:00      Cindy Amelia
# 39862 2017-02-13 16:37:00      Cindy Amelia
# 39863 2017-02-13 16:37:00      Cindy Amelia
# 39864 2017-02-13 16:38:00             Karin
# 39865 2017-02-13 16:39:00             Karin
# 39866 2017-02-13 16:48:00      Cindy Amelia
# 39867 2017-02-13 16:52:00             Karin
# 39868 2017-02-13 19:11:00            Benaya
# 39869 2017-02-13 19:11:00            Benaya
# 39870 2017-02-13 19:11:00            Benaya
#
#                                                     Text Short Date
# 0                                                  dayum 2015-04-01
# 1                                           Free d mana! 2015-04-01
# 2                                                      ? 2015-04-01
# 3                                    di ben and jerry's! 2015-04-01
# 4                                        <Media omitted> 2015-04-01
# 5                   Yg ambil maths ma cs jawabannya apa? 2015-04-01
# 6                                    Jwbnnya A bukan mot 2015-04-01
# 7                                                Lol bil 2015-04-01
# 8                                 17 juni ya mot. Wkwkwk 2015-04-01
# 9                                      Mnurut gw bukan 😂 2015-04-01
# 10                                           July 16 mot 2015-04-01
# 11                Gw gak tau sih yg bener apa actually 😂 2015-04-01
# 12                     May juni ud g mgkn y klo gt wkwww 2015-04-01
# 13                                 Pdhal ultah gw june 😔 2015-04-01
# 14                             Lolll bil. Kta gw 16 july 2015-04-01
# 15                                        September kali 2015-04-01
# 16      Iya kalo may ato june a bakal blg ke b "you m... 2015-04-01
# 17                                                     😞 2015-04-01
# 18                            Bulannya soalnya kan pasti 2015-04-01
# 19                                         July atau aug 2015-04-01
# 20                                S bernard jd tw krn it 2015-04-01
# 21      Trus kalau tgl nya 14 s bernard tetep gk bs n... 2015-04-01
# 22                            Tp ada yg flaw mnurut gw 😂 2015-04-01
# 23                                     Breakfast anyome? 2015-04-01
# 24                                               Yuk paz 2015-04-01
# 25                                                   Yuk 2015-04-01
# 26                   Gw nyusul ye. Mau choppe tmpt first 2015-04-01
# 27                                             Yuk quiki 2015-04-01
# 28                          Breakfast ga boleh cepet2 to 2015-04-01
# 29                                         Hrs dinikmati 2015-04-01
# ...                                                  ...        ...
# 39841                                                 Me 2017-02-01
# 39842                                     ^yeti sighting 2017-02-01
# 39843                                    <Media omitted> 2017-02-01
# 39844                                       ha ini apaan 2017-02-01
# 39845                                       gua ikut deh 2017-02-01
# 39846               Si @6581429830 juga mau ikut katanya 2017-02-01
# 39847                                gw juga ikut deh😂😂😂 2017-02-01
# 39848                                                  🤔 2017-02-01
# 39849                                 summon @6593737063 2017-02-01
# 39850                               Toto ada midterm ben 2017-02-01
# 39851                                               Hikz 2017-02-01
# 39852                               @6593229963 ikut ga? 2017-02-01
# 39853                                                yah 2017-02-01
# 39854                    gpp to payload selalu available 2017-02-01
# 39855                              W7 ada 5 midterms leh 2017-02-01
# 39856         My morality says its best to study at home 2017-02-01
# 39857                    @6586932864 ini this Friday ces 2017-02-01
# 39858                                       Bukan week 7 2017-02-01
# 39859                                                Lol 2017-02-01
# 39860                              kok lu nge tag ida si 2017-02-01
# 39861                                               HAHA 2017-02-01
# 39862                                      salah nge tag 2017-02-01
# 39863                                        @6593229963 2017-02-01
# 39864                                              HAHAA 2017-02-01
# 39865   Duh mel gw ga spinter lu yg bljrny bisa ngebu... 2017-02-01
# 39866             My morality says work hard pray hard 🚎 2017-02-01
# 39867                                                 🙊🙊 2017-02-01
# 39868     apparently gw dapet free one for one again lol 2017-02-01
# 39869                                    Expiring 17 feb 2017-02-01
# 39870                       Lemme know kalo ada yang mau 2017-02-01
#
# [39871 rows x 4 columns]

# %%
data['date_int'] = data['Short Date'].astype(np.int64)

# %%
date_count = data['date_int'].value_counts()
df = pd.DataFrame({'date':date_count.index, 'count':date_count.values})

# %%
df['real_date'] = df['date'].apply(lambda x: data['Short Date'][data['date_int'] == x].values[0])
df = df.sort_values('real_date')
df['real_date'] = df['real_date'].dt.strftime('%b/%y')
df
# Out:
#     count                 date real_date
# 0    3840  1427846400000000000    Apr/15
# 1    3662  1430438400000000000    May/15
# 13   1231  1433116800000000000    Jun/15
# 12   1366  1435708800000000000    Jul/15
# 8    2465  1438387200000000000    Aug/15
# 4    2808  1441065600000000000    Sep/15
# 6    2725  1443657600000000000    Oct/15
# 10   2091  1446336000000000000    Nov/15
# 15   1023  1448928000000000000    Dec/15
# 9    2332  1451606400000000000    Jan/16
# 2    2946  1454284800000000000    Feb/16
# 19    445  1456790400000000000    Mar/16
# 16    784  1464739200000000000    Jun/16
# 7    2706  1467331200000000000    Jul/16
# 3    2897  1470009600000000000    Aug/16
# 5    2738  1472688000000000000    Sep/16
# 14   1045  1475280000000000000    Oct/16
# 11   1386  1477958400000000000    Nov/16
# 18    505  1480550400000000000    Dec/16
# 17    746  1483228800000000000    Jan/17
# 20    130  1485907200000000000    Feb/17

# %%
plot = sns.barplot(x="real_date", y="count", data=df)
plot.figure.set_size_inches(20,10)

# %% [markdown]
# # PEAK HOUR

# %%
data['Short Time'] = data['Date'].apply(lambda x:x.time().strftime('%H'))
data['Short Time'] = pd.to_datetime(data['Short Time'], format="%H")

data['time_int'] = data['Short Time'].astype(np.int64)

date_count = data['time_int'].value_counts()
df = pd.DataFrame({'time':date_count.index, 'count':date_count.values})

df['real_date'] = df['time'].apply(lambda x: data['Short Time'][data['time_int'] == x].values[0])
df = df.sort_values('real_date')
df['real_date'] = df['real_date'].dt.strftime('%H')
df
# Out:
#     count                 time real_date
# 11   1636 -2208988800000000000        00
# 16    513 -2208985200000000000        01
# 18    200 -2208981600000000000        02
# 19    166 -2208978000000000000        03
# 21     33 -2208974400000000000        04
# 23      8 -2208970800000000000        05
# 22     29 -2208967200000000000        06
# 20    127 -2208963600000000000        07
# 17    503 -2208960000000000000        08
# 15   1165 -2208956400000000000        09
# 13   1579 -2208952800000000000        10
# 4    2868 -2208949200000000000        11
# 0    3839 -2208945600000000000        12
# 6    2747 -2208942000000000000        13
# 9    2011 -2208938400000000000        14
# 14   1469 -2208934800000000000        15
# 12   1604 -2208931200000000000        16
# 7    2666 -2208927600000000000        17
# 1    3343 -2208924000000000000        18
# 3    3083 -2208920400000000000        19
# 10   1861 -2208916800000000000        20
# 8    2485 -2208913200000000000        21
# 2    3104 -2208909600000000000        22
# 5    2832 -2208906000000000000        23

# %%
plot = sns.barplot(x="real_date", y="count", data=df)
plot.figure.set_size_inches(20,10)

# %% [markdown]
# ## Peak around lunch and dinner and supper time
